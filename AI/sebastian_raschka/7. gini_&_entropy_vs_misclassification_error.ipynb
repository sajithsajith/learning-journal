# %% [markdown]
# ![image.png](attachment:image.png)
# $$
# \begin{array}{l}
# \text{where,}\\
# I \rightarrow \text{Impurity (either entropy, gini or misclassification error)}\\
# D \rightarrow \text{Parent node}\\
# D_{v} \rightarrow \text{Child Node}
# \end{array}
# $$

# %% [markdown]
# ![image.png](attachment:image.png)
# $$
# p(i|x_{j}) \rightarrow \text{proportion of labels for class i}
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# $$
# \text{It uses majority voting.}\\
# \text{Ex: [0,0,1,1,1,1]} \rightarrow \text{1}
# \text{where,}\\
# \text{accuracy} \rightarrow \frac{4}{6}\\
# \text{error} \rightarrow \frac{2}{6}
# $$

# %% [markdown]
# $\text{Entropy}\\$
# ![image.png](attachment:image.png)
# $$
# \begin{aligned}
# &\text{child 1: 0.971}(0.971 > 0.918) \rightarrow \text{worse}\\
# &\text{child 2: 0.795}(0.971 > 0.795) \rightarrow \text{better}
# \end{aligned}
# $$

# %% [markdown]
# $\text{Misclassification Error}\\$
# ![image.png](attachment:image.png)
# $$
# \text{If the information gain is 0, we don't do the split, we look for other features because there is nothing to gain}\\
# $$

# %% [markdown]
# ![image.png](attachment:image.png)
# $$
# \begin{array}{l}
# \star \text{This figure summarizes why the misclassification error is not good as the entropy or gini}\\
# \star \text{Misclassification error somtimes get stuck when the information gain is 0. Entropy is concave but the misclassification error is not concave}\\
# \star \text{The average of the child nodes is always below the parent node}\\
# \star \text{Example:}\\
# \end{array}\\
# \text{    [50, 50]}\\
# \text{/\textbackslash }\\
# \text{[25, 25] [25, 25]}\\
# \begin{array}{l}
# \star \text{Eventhough we don't make an improvement here, we actually grow the decision tree. hence the entropy prevent us from getting stuck}\\
# \end{array}\\
# $$
