# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If we have a node which splits into 10 subnodes, then
#
# $$
# -10\left(\frac{1}{10} \log_{2} \left(\frac{1}{10}\right)\right)\\
# \text{= 3.32}
# $$
#
# The larger the feature, the larger the entropy, the larger the split info, the smaller the gain

# %% [markdown]
# ![image.png](attachment:image.png)
#
# If we have multiple nodes, the straight line grows like stairs so it is more prone to overfitting
#
# ```javascript
# Decision Boundary:
# |_
#   |_
#     |_
#       |_
#
# Nodes:
#       o
#      / \
#     o   o
#    /\   /\
#   o  o o  o
# ```

# %% [markdown]
# ![image.png](attachment:image.png)
#
# The deeper the trees becomes, the greater the training accuracy but lesser the test(independent data) accuracy
#
# The test (unseen data) accuracy was higher initially because of the fewer splits of trees, when the split goes on, the test accuracy decreases

# %% [markdown]
# ### To avoid Overfitting:
#
# ![image.png](attachment:image.png)

# %%
16:16
